# %%
import numpy as np
import yfinance as yf
import pandas as pd
from datetime import datetime

# %%
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import matplotlib.pyplot as plt

# %%
nse_stocks = [
    "RELIANCE.NS",   # Reliance Industries Limited
    "TCS.NS",        # Tata Consultancy Services
    "HDFCBANK.NS",   # HDFC Bank Limited
    "INFY.NS",       # Infosys Limited
    "ICICIBANK.NS",  # ICICI Bank Limited
    "KOTAKBANK.NS",  # Kotak Mahindra Bank Limited
    "HINDUNILVR.NS", # Hindustan Unilever Limited
    "LT.NS",         # Larsen & Toubro Limited
    "SBIN.NS",       # State Bank of India
    "BHARTIARTL.NS", # Bharti Airtel Limited
    "ITC.NS",        # ITC Limited
    "BAJFINANCE.NS", # Bajaj Finance Limited
    "AXISBANK.NS",   # Axis Bank Limited
    "HCLTECH.NS",    # HCL Technologies Limited
    "MARUTI.NS",     # Maruti Suzuki India Limited
    "M&M.NS",        # Mahindra & Mahindra Limited
    "ASIANPAINT.NS", # Asian Paints Limited
    "NESTLEIND.NS",  # Nestlé India Limited
    "ULTRACEMCO.NS", # UltraTech Cement Limited
    "SUNPHARMA.NS",  # Sun Pharmaceutical Industries Limited
    "TITAN.NS",      # Titan Company Limited
    "DRREDDY.NS",    # Dr. Reddy's Laboratories Limited
    "WIPRO.NS",      # Wipro Limited
    "ADANIPORTS.NS", # Adani Ports and Special Economic Zone Limited
    "POWERGRID.NS",  # Power Grid Corporation of India Limited
    "GRASIM.NS",     # Grasim Industries Limited
    "NTPC.NS",       # NTPC Limited
    "ONGC.NS",       # Oil and Natural Gas Corporation Limited
    "INDUSINDBK.NS", # IndusInd Bank Limited
    "BAJAJFINSV.NS"  # Bajaj Finserv Limited
]

# %%
start_date = "2019-01-01"
end_date = str(datetime.now().date())

dfs = {}

# %%
for ticker in nse_stocks:
    df = yf.download(ticker, start=start_date, end=end_date)
    df.reset_index(inplace=True)
    dfs[ticker] = df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for ticker in nse_stocks:
    dfs[ticker] = dfs[ticker][['Date', 'Close']]

# %%
def create_stock_sequences(df, sequence_length=60):
    df_copy = df.copy()
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    df_copy['Close_scaled'] = scaler.fit_transform(df_copy[['Close']])
    
    close_prices = df_copy['Close_scaled'].values
    
    X, y = [], []
    for i in range(sequence_length, len(close_prices)):
        X.append(close_prices[i-sequence_length:i])
        y.append(close_prices[i])
    
    X = np.array(X)
    y = np.array(y)
    
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    
    dates = df_copy['Date'].values[sequence_length:]
    
    return X, y, scaler, dates

# %%
stock_sequences = {}

for ticker, df in dfs.items():
    df = df[['Date', 'Close']]
    
    X, y, scaler, dates = create_stock_sequences(df, sequence_length=60)
    
    stock_sequences[ticker] = {
        'X': X,
        'y': y,
        'scaler': scaler,
        'dates': dates
    }
    
    print(f"{ticker} - X shape: {X.shape}, y shape: {y.shape}")
# Out:
# RELIANCE.NS - X shape: (1450, 60, 1), y shape: (1450,)
# TCS.NS - X shape: (1450, 60, 1), y shape: (1450,)
# HDFCBANK.NS - X shape: (1449, 60, 1), y shape: (1449,)
# INFY.NS - X shape: (1450, 60, 1), y shape: (1450,)
# ICICIBANK.NS - X shape: (1450, 60, 1), y shape: (1450,)
# KOTAKBANK.NS - X shape: (1449, 60, 1), y shape: (1449,)
# HINDUNILVR.NS - X shape: (1450, 60, 1), y shape: (1450,)
# LT.NS - X shape: (1450, 60, 1), y shape: (1450,)
# SBIN.NS - X shape: (1450, 60, 1), y shape: (1450,)
# BHARTIARTL.NS - X shape: (1449, 60, 1), y shape: (1449,)
# ITC.NS - X shape: (1450, 60, 1), y shape: (1450,)
# BAJFINANCE.NS - X shape: (1450, 60, 1), y shape: (1450,)
# AXISBANK.NS - X shape: (1450, 60, 1), y shape: (1450,)
# HCLTECH.NS - X shape: (1449, 60, 1), y shape: (1449,)
# MARUTI.NS - X shape: (1449, 60, 1), y shape: (1449,)
# M&M.NS - X shape: (1450, 60, 1), y shape: (1450,)
# ASIANPAINT.NS - X shape: (1449, 60, 1), y shape: (1449,)
# NESTLEIND.NS - X shape: (1450, 60, 1), y shape: (1450,)
# ULTRACEMCO.NS - X shape: (1450, 60, 1), y shape: (1450,)
# SUNPHARMA.NS - X shape: (1450, 60, 1), y shape: (1450,)
# TITAN.NS - X shape: (1449, 60, 1), y shape: (1449,)
# DRREDDY.NS - X shape: (1449, 60, 1), y shape: (1449,)
# WIPRO.NS - X shape: (1449, 60, 1), y shape: (1449,)
# ADANIPORTS.NS - X shape: (1450, 60, 1), y shape: (1450,)
# POWERGRID.NS - X shape: (1450, 60, 1), y shape: (1450,)
# GRASIM.NS - X shape: (1449, 60, 1), y shape: (1449,)
# NTPC.NS - X shape: (1450, 60, 1), y shape: (1450,)
# ONGC.NS - X shape: (1450, 60, 1), y shape: (1450,)
# INDUSINDBK.NS - X shape: (1450, 60, 1), y shape: (1450,)
# BAJAJFINSV.NS - X shape: (1450, 60, 1), y shape: (1450,)

# %%
def build_model(input_shape):
    model = Sequential()
    
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))
    
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))

    model.add(Dense(units=1))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

# %%
early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

# %%
X_train = stock_sequences["AXISBANK.NS"]['X']
y_train = stock_sequences["AXISBANK.NS"]['y']

model = build_model((X_train.shape[1], X_train.shape[2]))

history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    verbose=1,
    callbacks=[early_stop]
)

print(f"Finished training model for RELIANCE.NS")
# Out:
# Epoch 1/50
# 46/46 [==============================] - 6s 35ms/step - loss: 0.0312
# Epoch 2/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0054
# Epoch 3/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0050
# Epoch 4/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0046
# Epoch 5/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0048
# Epoch 6/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0047
# Epoch 7/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0041
# Epoch 8/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0044
# Epoch 9/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0045
# Epoch 10/50
# 46/46 [==============================] - 3s 76ms/step - loss: 0.0036
# Epoch 11/50
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0037
# Epoch 12/50
# 46/46 [==============================] - 4s 89ms/step - loss: 0.0039
# Epoch 13/50
# 46/46 [==============================] - 4s 88ms/step - loss: 0.0031
# Epoch 14/50
# 46/46 [==============================] - 3s 75ms/step - loss: 0.0032
# Epoch 15/50
# 46/46 [==============================] - 3s 60ms/step - loss: 0.0032
# Epoch 16/50
# 46/46 [==============================] - 3s 67ms/step - loss: 0.0030
# Epoch 17/50
# 46/46 [==============================] - 3s 69ms/step - loss: 0.0031
# Epoch 18/50
# 46/46 [==============================] - 3s 71ms/step - loss: 0.0035
# Epoch 19/50
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0030
# Epoch 20/50
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0026
# Epoch 21/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0027
# Epoch 22/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0028
# Epoch 23/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0026
# Epoch 24/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0025
# Epoch 25/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 26/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 27/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0024
# Epoch 28/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0022
# Epoch 29/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0026
# Epoch 30/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0023
# Epoch 31/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0021
# Epoch 32/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 33/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 34/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0021
# Epoch 35/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0018
# Epoch 36/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0019
# Epoch 37/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0019
# Epoch 38/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Epoch 39/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Epoch 40/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Finished training model for MARUTI.NS

# %%
models = {}

for ticker, data in stock_sequences.items():
    X_train = data['X']
    y_train = data['y']
    
    model = build_model((X_train.shape[1], X_train.shape[2]))
    
    history = model.fit(
        X_train,
        y_train,
        epochs=50,
        batch_size=32,
        verbose=1,
        callbacks=[early_stop]
    )
    
    models[ticker] = model
    
    print(f"Finished training model for {ticker}")
# Out:
# Epoch 1/50
# 46/46 [==============================] - 6s 39ms/step - loss: 0.0414
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0057
# Epoch 3/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0049
# Epoch 4/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0044
# Epoch 5/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0040
# Epoch 6/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0040
# Epoch 7/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0037
# Epoch 8/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0042
# Epoch 9/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0046
# Epoch 10/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0036
# Epoch 11/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0036
# Epoch 12/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0043
# Epoch 13/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0032
# Epoch 14/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0036
# Epoch 15/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0032
# Epoch 16/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0033
# Epoch 17/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0033
# Epoch 18/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0030
# Epoch 19/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0032
# Epoch 20/50
# 46/46 [==============================] - 2s 48ms/step - loss: 0.0030
# Epoch 21/50
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0028
# Epoch 22/50
# 46/46 [==============================] - 3s 66ms/step - loss: 0.0028
# Epoch 23/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0028
# Epoch 24/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0028
# Epoch 25/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0027
# Epoch 26/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 27/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 28/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0026
# Epoch 29/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0027
# Epoch 30/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0025
# Epoch 31/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 32/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 33/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0025
# Epoch 34/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0025
# Epoch 35/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0024
# Epoch 36/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 37/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0021
# Epoch 38/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0021
# Epoch 39/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0020
# Epoch 40/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0020
# Epoch 41/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 42/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0019
# Epoch 43/50
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0020
# Epoch 44/50
# 46/46 [==============================] - 2s 48ms/step - loss: 0.0020
# Epoch 45/50
# 46/46 [==============================] - 3s 70ms/step - loss: 0.0018
# Epoch 46/50
# 46/46 [==============================] - 3s 59ms/step - loss: 0.0023
# Epoch 47/50
# 46/46 [==============================] - 3s 70ms/step - loss: 0.0019
# Epoch 48/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0017
# Epoch 49/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0018
# Epoch 50/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0016
# Finished training model for RELIANCE.NS
# Epoch 1/50
# 46/46 [==============================] - 7s 72ms/step - loss: 0.0341
# Epoch 2/50
# 46/46 [==============================] - 3s 59ms/step - loss: 0.0051
# Epoch 3/50
# 46/46 [==============================] - 3s 63ms/step - loss: 0.0046
# Epoch 4/50
# 46/46 [==============================] - 3s 65ms/step - loss: 0.0043
# Epoch 5/50
# 46/46 [==============================] - 3s 64ms/step - loss: 0.0040
# Epoch 6/50
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0041
# Epoch 7/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0047
# Epoch 8/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0038
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0036
# Epoch 10/50
# 46/46 [==============================] - 3s 59ms/step - loss: 0.0036
# Epoch 11/50
# 46/46 [==============================] - 3s 73ms/step - loss: 0.0038
# Epoch 12/50
# 46/46 [==============================] - 4s 96ms/step - loss: 0.0032
# Epoch 13/50
# 46/46 [==============================] - 4s 83ms/step - loss: 0.0032
# Epoch 14/50
# 46/46 [==============================] - 3s 68ms/step - loss: 0.0033
# Epoch 15/50
# 46/46 [==============================] - 4s 79ms/step - loss: 0.0032
# Epoch 16/50
# 46/46 [==============================] - 4s 91ms/step - loss: 0.0030
# Epoch 17/50
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0030
# Epoch 18/50
# 46/46 [==============================] - 4s 82ms/step - loss: 0.0029
# Epoch 19/50
# 46/46 [==============================] - 4s 84ms/step - loss: 0.0029
# Epoch 20/50
# 46/46 [==============================] - 4s 86ms/step - loss: 0.0028
# Epoch 21/50
# 46/46 [==============================] - 2s 49ms/step - loss: 0.0031
# Epoch 22/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0029
# Epoch 23/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0036
# Epoch 24/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0028
# Epoch 25/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0027
# Epoch 26/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 27/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0023
# Epoch 28/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0024
# Epoch 29/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0025
# Epoch 30/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0024
# Epoch 31/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0024
# Epoch 32/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0023
# Finished training model for TCS.NS
# Epoch 1/50
# 46/46 [==============================] - 6s 42ms/step - loss: 0.0415
# Epoch 2/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0070
# Epoch 3/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0067
# Epoch 4/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0061
# Epoch 5/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0051
# Epoch 6/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0053
# Epoch 7/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0061
# Epoch 8/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0056
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0058
# Epoch 10/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0048
# Epoch 11/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0047
# Epoch 12/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0044
# Epoch 13/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0045
# Epoch 14/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0044
# Epoch 15/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0040
# Epoch 16/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0040
# Epoch 17/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0039
# Epoch 18/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0040
# Epoch 19/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0041
# Epoch 20/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0037
# Epoch 21/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0037
# Epoch 22/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0043
# Epoch 23/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0035
# Epoch 24/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0034
# Epoch 25/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0034
# Epoch 26/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0033
# Epoch 27/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0032
# Epoch 28/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0033
# Epoch 29/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0032
# Epoch 30/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0032
# Epoch 31/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0033
# Epoch 32/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0030
# Epoch 33/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0029
# Epoch 34/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0033
# Epoch 35/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0030
# Epoch 36/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0026
# Epoch 37/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0028
# Epoch 38/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0027
# Epoch 39/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0027
# Epoch 40/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0026
# Epoch 41/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0027
# Epoch 42/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0024
# Epoch 43/50
# 46/46 [==============================] - 1s 23ms/step - loss: 0.0024
# Epoch 44/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0025
# Epoch 45/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 46/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 47/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0024
# Epoch 48/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0023
# Epoch 49/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 50/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0019
# Finished training model for HDFCBANK.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 34ms/step - loss: 0.0315
# Epoch 2/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0062
# Epoch 3/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0050
# Epoch 4/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0046
# Epoch 5/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0047
# Epoch 6/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0043
# Epoch 7/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0042
# Epoch 8/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0041
# Epoch 9/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0036
# Epoch 10/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0035
# Epoch 11/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0037
# Epoch 12/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0034
# Epoch 13/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0033
# Epoch 14/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0030
# Epoch 15/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0029
# Epoch 16/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0032
# Epoch 17/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0032
# Epoch 18/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0028
# Epoch 19/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0031
# Epoch 20/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0034
# Epoch 21/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 22/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0029
# Epoch 23/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0027
# Epoch 24/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0028
# Epoch 25/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0025
# Epoch 26/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0028
# Epoch 27/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0026
# Epoch 28/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0024
# Epoch 29/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0025
# Epoch 30/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0024
# Epoch 31/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0022
# Epoch 32/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0022
# Epoch 33/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0023
# Epoch 34/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0021
# Epoch 35/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0022
# Epoch 36/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0024
# Epoch 37/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0022
# Epoch 38/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0023
# Epoch 39/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0022
# Finished training model for INFY.NS
# Epoch 1/50
# 46/46 [==============================] - 10s 85ms/step - loss: 0.0307
# Epoch 2/50
# 46/46 [==============================] - 4s 83ms/step - loss: 0.0041
# Epoch 3/50
# 46/46 [==============================] - 4s 81ms/step - loss: 0.0034
# Epoch 4/50
# 46/46 [==============================] - 3s 61ms/step - loss: 0.0033
# Epoch 5/50
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0032
# Epoch 6/50
# 46/46 [==============================] - 2s 54ms/step - loss: 0.0032
# Epoch 7/50
# 46/46 [==============================] - 3s 56ms/step - loss: 0.0030
# Epoch 8/50
# 46/46 [==============================] - 2s 53ms/step - loss: 0.0031
# Epoch 9/50
# 46/46 [==============================] - 2s 54ms/step - loss: 0.0030
# Epoch 10/50
# 46/46 [==============================] - 3s 68ms/step - loss: 0.0029
# Epoch 11/50
# 46/46 [==============================] - 4s 76ms/step - loss: 0.0027
# Epoch 12/50
# 46/46 [==============================] - 3s 67ms/step - loss: 0.0024
# Epoch 13/50
# 46/46 [==============================] - 3s 74ms/step - loss: 0.0024
# Epoch 14/50
# 46/46 [==============================] - 3s 63ms/step - loss: 0.0028
# Epoch 15/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0025
# Epoch 16/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0023
# Epoch 17/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0021
# Epoch 18/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0023
# Epoch 19/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0022
# Epoch 20/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0026
# Epoch 21/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0024
# Epoch 22/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0020
# Epoch 23/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0020
# Epoch 24/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0020
# Epoch 25/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0023
# Epoch 26/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0018
# Epoch 27/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0021
# Epoch 28/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0021
# Epoch 29/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0016
# Epoch 30/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0017
# Epoch 31/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0019
# Epoch 32/50
# 46/46 [==============================] - 1s 33ms/step - loss: 0.0018
# Epoch 33/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0018
# Epoch 34/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0017
# Finished training model for ICICIBANK.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 33ms/step - loss: 0.0277
# Epoch 2/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0083
# Epoch 3/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0071
# Epoch 4/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0068
# Epoch 5/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0063
# Epoch 6/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0070
# Epoch 7/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0059
# Epoch 8/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0068
# Epoch 9/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0056
# Epoch 10/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0055
# Epoch 11/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0050
# Epoch 12/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0048
# Epoch 13/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0051
# Epoch 14/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0047
# Epoch 15/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0047
# Epoch 16/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0045
# Epoch 17/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0044
# Epoch 18/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0041
# Epoch 19/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0042
# Epoch 20/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0041
# Epoch 21/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0044
# Epoch 22/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0039
# Epoch 23/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0037
# Epoch 24/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0039
# Epoch 25/50
# 46/46 [==============================] - 2s 50ms/step - loss: 0.0037
# Epoch 26/50
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0038
# Epoch 27/50
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0034
# Epoch 28/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0035
# Epoch 29/50
# 46/46 [==============================] - 2s 50ms/step - loss: 0.0033
# Epoch 30/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0032
# Epoch 31/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0031
# Epoch 32/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0033
# Epoch 33/50
# 46/46 [==============================] - 2s 50ms/step - loss: 0.0030
# Epoch 34/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0031
# Epoch 35/50
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0031
# Epoch 36/50
# 46/46 [==============================] - 2s 50ms/step - loss: 0.0029
# Epoch 37/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0026
# Epoch 38/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0027
# Epoch 39/50
# 46/46 [==============================] - 2s 50ms/step - loss: 0.0031
# Epoch 40/50
# 46/46 [==============================] - 2s 52ms/step - loss: 0.0025
# Epoch 41/50
# 46/46 [==============================] - 3s 56ms/step - loss: 0.0028
# Epoch 42/50
# 46/46 [==============================] - 8s 173ms/step - loss: 0.0027
# Epoch 43/50
# 46/46 [==============================] - 3s 64ms/step - loss: 0.0026
# Epoch 44/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 45/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0025
# Epoch 46/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 47/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0022
# Epoch 48/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 49/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0024
# Epoch 50/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0022
# Finished training model for KOTAKBANK.NS
# Epoch 1/50
# 46/46 [==============================] - 6s 36ms/step - loss: 0.0286
# Epoch 2/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.0064
# Epoch 3/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.0061
# Epoch 4/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0056
# Epoch 5/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0053
# Epoch 6/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0048
# Epoch 7/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0048
# Epoch 8/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0043
# Epoch 9/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0042
# Epoch 10/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0042
# Epoch 11/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0038
# Epoch 12/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0037
# Epoch 13/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0035
# Epoch 14/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0036
# Epoch 15/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0035
# Epoch 16/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0036
# Epoch 17/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0032
# Epoch 18/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0033
# Epoch 19/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0033
# Epoch 20/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0029
# Epoch 21/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0029
# Epoch 22/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0030
# Epoch 23/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 24/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0030
# Epoch 25/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0029
# Epoch 26/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0028
# Epoch 27/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 28/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0028
# Epoch 29/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 30/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0025
# Epoch 31/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 32/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0026
# Epoch 33/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 34/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 35/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0023
# Epoch 36/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0021
# Epoch 37/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0021
# Epoch 38/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 39/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0021
# Epoch 40/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0021
# Epoch 41/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0021
# Epoch 42/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0020
# Epoch 43/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0020
# Epoch 44/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Epoch 45/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0020
# Epoch 46/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0020
# Epoch 47/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0019
# Epoch 48/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0018
# Epoch 49/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0021
# Epoch 50/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0018
# Finished training model for HINDUNILVR.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 34ms/step - loss: 0.0320
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0043
# Epoch 3/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0035
# Epoch 4/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0032
# Epoch 5/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0027
# Epoch 6/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0029
# Epoch 7/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0031
# Epoch 8/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0030
# Epoch 9/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 10/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0027
# Epoch 11/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0025
# Epoch 12/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 13/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0031
# Epoch 14/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0025
# Epoch 15/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0025
# Epoch 16/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0027
# Epoch 17/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 18/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0024
# Epoch 19/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 20/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Epoch 21/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0025
# Epoch 22/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 23/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0020
# Epoch 24/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0022
# Epoch 25/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0018
# Epoch 26/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0016
# Epoch 27/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0020
# Epoch 28/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0018
# Epoch 29/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0017
# Epoch 30/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0018
# Epoch 31/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0019
# Finished training model for LT.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 35ms/step - loss: 0.0203
# Epoch 2/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0037
# Epoch 3/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0036
# Epoch 4/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0036
# Epoch 5/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0037
# Epoch 6/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0030
# Epoch 7/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0031
# Epoch 8/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0029
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0037
# Epoch 10/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0028
# Epoch 11/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0027
# Epoch 12/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0027
# Epoch 13/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0024
# Epoch 14/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 15/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0028
# Epoch 16/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0028
# Epoch 17/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0023
# Epoch 18/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0022
# Epoch 19/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0025
# Epoch 20/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0021
# Epoch 21/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0023
# Epoch 22/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0019
# Epoch 23/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0020
# Epoch 24/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0020
# Epoch 25/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0023
# Epoch 26/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0024
# Epoch 27/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0020
# Finished training model for SBIN.NS
# Epoch 1/50
# 46/46 [==============================] - 6s 36ms/step - loss: 0.0202
# Epoch 2/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0026
# Epoch 3/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0023
# Epoch 4/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0021
# Epoch 5/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0021
# Epoch 6/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0020
# Epoch 7/50
# 46/46 [==============================] - 1s 32ms/step - loss: 0.0018
# Epoch 8/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0018
# Epoch 9/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0016
# Epoch 10/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0015
# Epoch 11/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0016
# Epoch 12/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0015
# Epoch 13/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0023
# Epoch 14/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0015
# Epoch 15/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0015
# Finished training model for BHARTIARTL.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 34ms/step - loss: 0.0230
# Epoch 2/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0038
# Epoch 3/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0032
# Epoch 4/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0029
# Epoch 5/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0029
# Epoch 6/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0031
# Epoch 7/50
# 46/46 [==============================] - 2s 47ms/step - loss: 0.0027
# Epoch 8/50
# 46/46 [==============================] - 2s 51ms/step - loss: 0.0025
# Epoch 9/50
# 46/46 [==============================] - 3s 68ms/step - loss: 0.0025
# Epoch 10/50
# 46/46 [==============================] - 3s 61ms/step - loss: 0.0027
# Epoch 11/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0032
# Epoch 12/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0027
# Epoch 13/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0029
# Finished training model for ITC.NS
# Epoch 1/50
# 46/46 [==============================] - 7s 37ms/step - loss: 0.0438
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0071
# Epoch 3/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0065
# Epoch 4/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.0069
# Epoch 5/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0060
# Epoch 6/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0057
# Epoch 7/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0051
# Epoch 8/50
# 46/46 [==============================] - 3s 56ms/step - loss: 0.0046
# Epoch 9/50
# 46/46 [==============================] - 3s 63ms/step - loss: 0.0046
# Epoch 10/50
# 46/46 [==============================] - 3s 60ms/step - loss: 0.0049
# Epoch 11/50
# 46/46 [==============================] - 3s 60ms/step - loss: 0.0049
# Epoch 12/50
# 46/46 [==============================] - 3s 63ms/step - loss: 0.0051
# Epoch 13/50
# 46/46 [==============================] - 3s 60ms/step - loss: 0.0041
# Epoch 14/50
# 46/46 [==============================] - 3s 62ms/step - loss: 0.0045
# Epoch 15/50
# 46/46 [==============================] - 3s 61ms/step - loss: 0.0040
# Epoch 16/50
# 46/46 [==============================] - 3s 61ms/step - loss: 0.0037
# Epoch 17/50
# 46/46 [==============================] - 3s 69ms/step - loss: 0.0039
# Epoch 18/50
# 46/46 [==============================] - 3s 65ms/step - loss: 0.0038
# Epoch 19/50
# 46/46 [==============================] - 3s 63ms/step - loss: 0.0041
# Epoch 20/50
# 46/46 [==============================] - 3s 61ms/step - loss: 0.0037
# Epoch 21/50
# 46/46 [==============================] - 3s 64ms/step - loss: 0.0037
# Finished training model for BAJFINANCE.NS
# Epoch 1/50
# 46/46 [==============================] - 8s 38ms/step - loss: 0.0428
# Epoch 2/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.0057
# Epoch 3/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0046
# Epoch 4/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0047
# Epoch 5/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0043
# Epoch 6/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0041
# Epoch 7/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0040
# Epoch 8/50
# 46/46 [==============================] - 2s 41ms/step - loss: 0.0037
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0037
# Epoch 10/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0033
# Epoch 11/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0036
# Epoch 12/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0032
# Epoch 13/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0032
# Epoch 14/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0040
# Epoch 15/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0036
# Epoch 16/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0034
# Epoch 17/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0033
# Epoch 18/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0028
# Epoch 19/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0032
# Epoch 20/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0028
# Epoch 21/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 22/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0027
# Epoch 23/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0026
# Epoch 24/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0025
# Epoch 25/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0025
# Epoch 26/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 27/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0026
# Epoch 28/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0024
# Epoch 29/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 30/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0021
# Epoch 31/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0023
# Epoch 32/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0019
# Epoch 33/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0022
# Epoch 34/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0021
# Epoch 35/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0021
# Epoch 36/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0021
# Epoch 37/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0022
# Finished training model for AXISBANK.NS
# Epoch 1/50
# 46/46 [==============================] - 5s 36ms/step - loss: 0.0157
# Epoch 2/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0030
# Epoch 3/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0026
# Epoch 4/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0028
# Epoch 5/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0031
# Epoch 6/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0023
# Epoch 7/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0023
# Epoch 8/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0025
# Epoch 9/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0021
# Epoch 10/50
# 46/46 [==============================] - 2s 33ms/step - loss: 0.0021
# Epoch 11/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0022
# Epoch 12/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0020
# Epoch 13/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0022
# Epoch 14/50
# 46/46 [==============================] - 2s 39ms/step - loss: 0.0016
# Epoch 15/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0018
# Epoch 16/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0018
# Epoch 17/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0018
# Epoch 18/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0020
# Epoch 19/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0021
# Finished training model for HCLTECH.NS
# Epoch 1/50
# 46/46 [==============================] - 7s 42ms/step - loss: 0.0271
# Epoch 2/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0045
# Epoch 3/50
# 46/46 [==============================] - 2s 40ms/step - loss: 0.0039
# Epoch 4/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0039
# Epoch 5/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0041
# Epoch 6/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0035
# Epoch 7/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0033
# Epoch 8/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0034
# Epoch 9/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0038
# Epoch 10/50
# 46/46 [==============================] - 2s 36ms/step - loss: 0.0031
# Epoch 11/50
# 46/46 [==============================] - 2s 34ms/step - loss: 0.0031
# Epoch 12/50
# 46/46 [==============================] - 2s 35ms/step - loss: 0.0033
# Epoch 13/50
# 46/46 [==============================] - 2s 38ms/step - loss: 0.0030
# Epoch 14/50
# 46/46 [==============================] - 2s 37ms/step - loss: 0.0027
# Epoch 15/50
# 26/46 [===============>..............] - ETA: 0s - loss: 0.0027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 9
#       5 y_train = data['y']
#       7 model = build_model((X_train.shape[1], X_train.shape[2]))
# ----> 9 history = model.fit(
#      10     X_train,
#      11     y_train,
#      12     epochs=50,
#      13     batch_size=32,
#      14     verbose=1,
#      15     callbacks=[early_stop]
#      16 )
#      18 models[ticker] = model
#      20 print(f"Finished training model for {ticker}")
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Coding\anaconda3\envs\ML38\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
data = stock_sequences["RELIANCE.NS"]
scaler = data['scaler']
dates = data['dates']
X_train = data['X']
y_train = data['y']

last_sequence = X_train[-1]

num_future_days = 15

future_predictions_scaled = []
last_date = pd.to_datetime(dates[-1])
future_dates = []

current_sequence = last_sequence.copy()

for i in range(num_future_days):
    current_sequence_reshaped = current_sequence.reshape(1, current_sequence.shape[0], 1)
    next_pred_scaled = model.predict(current_sequence_reshaped)
    future_predictions_scaled.append(next_pred_scaled[0, 0])
    current_sequence = np.append(current_sequence[1:], [[next_pred_scaled[0, 0]]], axis=0)
    last_date = last_date + pd.Timedelta(days=1)
    future_dates.append(last_date)

future_predictions_scaled = np.array(future_predictions_scaled)
future_predictions = scaler.inverse_transform(future_predictions_scaled.reshape(-1, 1))

last_60_actual_scaled = y_train[-60:]
last_60_actual = scaler.inverse_transform(last_60_actual_scaled.reshape(-1, 1))
last_60_dates = pd.to_datetime(dates[-60:])

plt.figure(figsize=(12, 6))
plt.plot(last_60_dates, last_60_actual, label="Last 60 Days Actual", color='blue')
plt.plot(future_dates, future_predictions, label="Next Month Predicted", color='red', marker='o')
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title(f"{ticker} - Last 60 Days Actual vs Next Month Predicted Prices")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
for ticker, data in stock_sequences.items():
    model = models[ticker]
    
    scaler = data['scaler']
    dates = data['dates']
    X = data['X']
    y = data['y']
    
    predictions_scaled = model.predict(X)
    
    predictions = scaler.inverse_transform(predictions_scaled)
    actual = scaler.inverse_transform(y.reshape(-1, 1))
    
    last_60_dates = dates[-60:]
    last_60_predictions = predictions[-60:]
    last_60_actual = actual[-60:]

    plt.figure(figsize=(10, 6))
    plt.plot(last_60_dates, last_60_actual, color='blue', label='Actual Price')
    plt.plot(last_60_dates, last_60_predictions, color='red', label='Predicted Price')
    plt.title(f"{ticker}: Last 60 Days - Actual vs Predicted Prices")
    plt.xlabel("Date")
    plt.ylabel("Stock Price")
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()
